# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players <- read_csv("Data/players.csv")
players
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# ...

# %%
mean_table <- players |>
  summarise(
    Mean_Played_Hours = mean(played_hours, na.rm = TRUE),
    Mean_Age = mean(Age, na.rm = TRUE)
  )

mean_table
# Out:
#   Mean_Played_Hours Mean_Age
# 1 5.845918          21.13918

# %%
options(repr.plot.width = 10, repr.plot.height = 7)

Question_Plot <- players |>
    ggplot(aes(x = Age, y = played_hours, color = subscribe)) +
        geom_point() +
        coord_cartesian(ylim = c(0,6)) +
        labs(x = "Player Age", y = "Player Playtime", color = "Did they Subscribe")
    
Question_Plot
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
sessions <- read_csv("Data/sessions.csv")
sessions <- sessions |>
mutate(
    start_time = dmy_hm(start_time),
    end_time = dmy_hm(end_time),
    start_date = as.Date(start_time), 
    original_start_time_posix = as.POSIXct(original_start_time / 1000, origin = "1970-01-01", tz = "UTC"),
     original_end_time_posix  = as.POSIXct(original_end_time / 1000, origin = "1970-01-01", tz = "UTC"),
    start_clock_time = format(start_time, "%H:%M"),
    end_date = as.Date(end_time),
    end_clock_time = format(end_time, "%H:%M")
  ) |>
mutate(
    original_start_date = as.Date(original_start_time_posix),
    original_start_clock_time = format(original_start_time_posix, "%H:%M"),
    original_end_date = as.Date(original_end_time_posix),
    original_end_clock_time = format(original_end_time_posix, "%H:%M")) |>  
select(hashedEmail, start_date, start_clock_time, end_date, end_clock_time,
         original_start_clock_time, original_end_clock_time, original_start_date, original_end_date)
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [raw]
# There are two datasets, one being the information about the players and the other being information about session times.
# The only variables they both share are hashed emails, and players consist of experience, “subscribe”, played_hours, name, gender, and age, while the  sessions dataset has start_time, end_time, original_start_time, and original_end_time.
#
# There are several untidy errors in the sessions dataset, most notably two pieces of data in the same column and a column that should be letters being numbers.I will address “What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?”, and the question I will be asking is can total playtime and their age have an effect on whether or not someone subscribes to the newsletter? I utilized a scatterplot in order to make a visualization, which showed me that a majority of players over the age of 30 chose not to subscribe to the newsletter, while players in the age range of 10-30 were much more likely to subscribe to the newsletter.
#
# The method that I want to propose is to figure out the target demographic of the newsletter by knn-classification. Some limitations occur when people above the age of 30 are tested, as there are significantly less players which could give us skewed data. I’ll use age and playtime as my independent variables, and split the data into training and testing sections. The split will happen before I fit the knn classifier, and I’ll split the data 70/30 training testing. Knn classification works best with the data I am using because its simple and non-parametric which allows me to identify natural groupings in the data. It also assumes that players in similar ranges in terms of my variables will have similar subscription behaviors, and that the variables are scaled to ensure that outliers don't dominate the prediction. I'd incorporate k-fold cross-validation within the training data, as it ensures that the relationship between age, playtime, and subscriptions is consistent among the subsets of data.
